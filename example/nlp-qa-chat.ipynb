# %%
import json

with open('../2022/onet-qa-sci-2022-20.json', mode='r', encoding='utf-8') as fo:
    corpus = json.loads(fo.read())

corpus
# Out:
# [{'id': 1,
#   'question': 'ความสัมพันธ์ระหว่างสิ่งมีชีวิตกับสิ่งมีชีวิตในข้อใดจัดเป็นการอยู่ร่วมกันในรูปแบบ "ภาวะพึ่งพาอาศัยกัน"',
#   'choice': ['ปลาการ์ตูนกับปะการัง',
#    'ผึ้งกับดอกไม้',
#    'เห็บกับสุนัข',
#    'กล้วยไม้กับต้นมะค่า'],
#   'answer': 2},
#  {'id': 2,
#   'question': 'ในระบบย่อยอาหารของมนุษย์ การดูดซึมสารอาหารส่วนใหญ่เกิดขึ้นที่อวัยวะใด',
#   'choice': ['ลำไส้เล็ก', 'ตับอ่อน', 'ลำไส้ใหญ่', 'กระเพาะอาหาร'],
#   'answer': 1},
#  {'id': 3,
#   'question': 'ครอบครัวหนึ่ง พ่อและแม่มีผมสั้นสีดำ พ่อมีผมเหยียดตรง แต่แม่มีผมหยิกเป็นคลื่น จากการดัดผม ลูกสาวทำสีผมเป็นสีทาและดัดหยิกเป็นคลื่นเช่นเดียวกับกุณยาย\nข้อใดเป็นลักษณะทางพันธุกรรม',
#   'choice': ['ลักษณะผมสั้นที่พบในพ่อและแม่',
#    'ลักษณะผมสีดำที่พบในพ่อและแม่',
#    'ลักษณะผมสีเทาของคุณยายและหลานที่เหมือนกัน',
#    'ลักษณะผมหยิกที่ถ่ายทอดจากรุ่นคุณยายสู่หลาน'],
#   'answer': 2},
#  {'id': 4,
#   'question': 'ในการทดลองเกี่ยวกับสภาพยืดหยุ่น นำชิ้นงานที่มีความยาวเริ่มต้น 15 เซนติเมตร ทำการดึงด้วยแรงเท่ากัน ได้ผลการทดลองดังตาราง\nวัสดุในข้อใดเหมาะในการนำมาทำเป็นยางรัดของ',
#   'material': [{'type': 'table',
#     'data': '<table> <tbody> <th > <td rowspan="2" >วัสดุ</td> <td colspan="2" >ความยาวของชิ้นงาน (เซนติเมตร)</td> </th> <tr > <td>ขณะดึงวัตถุ</td> <td>หลังปล่อย</td> </tr> <tr > <td>A</td> <td>16</td> <td >16</td> </tr> <tr> <td >B</td> <td >19</td> <td >18</td> </tr> <tr> <td >C</td> <td>15</td> <td>15</td> </tr> <tr > <td>D</td> <td>23</td> <td >15</td> </tr> </tbody></table>'}],
#   'choice': ['A', 'B', 'C', 'D'],
#   'answer': 4},
#  {'id': 5,
#   'question': 'จากการสังเกตต่อไปนี้\nข้อใดเป็นการเปลี่ยนสถานะ',
#   'material': [{'type': 'list',
#     'data': ['A การวางเกล็ดการบูรไว้ เกล็ดการบูรมีขนาดเล็กลง',
#      'B การใส่เกลือลงไปในน้ำ เม็ดเกลือหายไป ได้ของเหลวใส ไม่มีสี',
#      'C การฉีดสเปรย์แอลกอฮอล์บนผิวหนัง แล้วแอลกอฮอล์หายไป',
#      'D การใส่น้ำแข็งลงไปในแก้วที่มีน้ำ น้ำแข็งหายไป ได้ของเหลวใส ไม่มีสี']}],
#   'choice': ['A B C', 'A B D', 'B C D', 'A C D'],
#   'answer': 4},
#  {'id': 6,
#   'question': 'นักเรียน 4 คน ทำการแยกสารด้วยวิธีการดังต่อไปนี้\nวิธีการใดเป็นการแยกสารที่เหมาะสมมากที่สุด',
#   'material': [{'type': 'list',
#     'data': ['A แยกเกลือแกงออกจากทรายโดยการร่อน',
#      'B แยกทรายออกจากเกลือแกงโดยการหยิบออก',
#      'C แยกตะปูเหล็กออกจากทรายโดยการกรอง',
#      'D แยกผงเหล็กออกจากทรายโดยการใช้แม่เหล็กดูด']}],
#   'choice': ['A', 'B', 'C', 'D'],
#   'answer': 4},
#  {'id': 7,
#   'question': 'ปล่อยก้อนหินขนาดเล็ก และใบไม้ ที่มีมวลเท่ากัน จากที่สูงเท่ากัน พบว่าก้อนหินตกถึงพื้นก่อนใบไม้\nข้อใดถูกต้องเกี่ยวกับน้ำหนักของก้อนหินและน้ำหนักของใบไม้',
#   'material': [{'type': 'list',
#     'data': ['A แยกเกลือแกงออกจากทรายโดยการร่อน',
#      'B แยกทรายออกจากเกลือแกงโดยการหยิบออก',
#      'C แยกตะปูเหล็กออกจากทรายโดยการกรอง',
#      'D แยกผงเหล็กออกจากทรายโดยการใช้แม่เหล็กดูด']}],
#   'choice': ['ก้อนหินมีน้ำหนักมากกว่าใบไม้ เพราะก้อนหินตกถึงพื้นก่อน',
#    'ก้อนหินมีน้ำหนักน้อยกว่าใบไม้ เพราะก้อนหินตกถึงพื้นก่อน',
#    'ก้อนหินและใบไม้มีน้ำหนักเท่ากัน เพราะมีมวลเท่ากัน',
#    'ก้อนหินและใบไม้มีน้ำหนักเท่ากัน เพราะวัตถุทั้งสองตกลงสู่พื้นโลกเหมือนกัน'],
#   'answer': 3},
#  {'id': 8,
#   'question': 'เด็กชายดำออกแรง 3 นิวตัน และเด็กชายแดงออกแรง 7 นิวตัน ดันกล่องใบหนึ่ง\nดังแสดงในรูป พบว่ากล่องอยู่นิ่ง\nจงหาแรงเสียดทานที่พื้นกระทำต่อกล่อง',
#   'material': [{'type': 'image-desc',
#     'data': ['รูปภาพแสดง วัตถุสี่เหลี่ยมตั้งอยู่พื้นตรงกลาง มีลูกศรแทนแรงชี้ไปยังตัววัตถุ โดยลูกศรทางซ้ายของวัตถุแทนแรง 3 นิวตัน และลูกศรทางขวาของวัตถุแทนแรง 7 นิวตัน']}],
#   'choice': ['4 นิวตันไปทางซ้าย',
#    '4 นิวตันไปทางขวา',
#    '10 นิวตันไปทางซ้าย',
#    '10 นิวตัน ไปทางขวา'],
#   'answer': 2},
#  {'id': 9,
#   'question': 'ข้อใดอธิบายเกี่ยวกับแรงไฟฟ้าได้ถูกต้อง',
#   'choice': ['เกิดได้โดยที่วัตถุไม่ต้องสัมผัสกัน',
#    'เป็นได้เฉพาะแรงผลักเท่านั้น',
#    'เป็นได้เฉพาะแรงดูดเท่านั้น',
#    'เป็นแรงด้านระหว่างวัตถุเท่านั้น'],
#   'answer': 1},
#  {'id': 10,
#   'question': 'ขวดแก้วทึบขนาดเท่ากัน 3 ขวด ใส่น้ำปริมาตรต่างกัน นายมานะต้องการพิสูจน์ว่า ขวดใดบรรจุน้ำไว้มากที่สุดโดยไม่เปีดขวด จึงเกาะที่ด้านล่างของขวดทั้ง 3 ขวด ด้วยแรงเท่า ๆ กัน นายมานะพบว่าขวดน้ำแต่ละขวดมีเสียงแตกต่างกัน\nข้อใดมีน้ำในขวดมากที่สุด',
#   'choice': ['ขวดที่เคาะแล้วได้ยินเสียงดังที่สุด',
#    'ขวดที่เคาะแล้วได้ยินเสียงค่อยที่สุด',
#    'ขวดที่เคาะแล้วได้ยินเสียงแหลมที่สุด',
#    'ขวดที่เคาะแล้วได้ยินเสียงทุ้มที่สุด'],
#   'answer': 4},
#  {'id': 12,
#   'question': 'ในคืนที่ฟ้าโปร่งไม่มีเมฆบัง เมื่อเงยหน้ามองไปบนท้องฟ้า ด.ญ. มานี เห็นดวงจันทร์ปรากฏดังรูป\nด.ญ. มานี ต้องรออีกประมาณกี่วัน หากต้องการถ่ายรูปดวงจันทร์เต็มดวง',
#   'material': [{'type': 'image-desc',
#     'data': ['รูปภาพแสดงดวงจันทร์เสี้ยว มีพื้นที่สว่างประมาณหนึ่งส่วนสองของวงกลม โดยมีด้านสว่างอยู่ทางด้านล่าง']}],
#   'choice': ['3-4 วัน', '6-8 วัน', '14-16 วัน', '29-31 วัน'],
#   'answer': 2},
#  {'id': 14,
#   'question': 'จากการสำรวจหินบริเวณหนึ่งพบหิน 4 ก้อน ได้แก่ A B C D ทีมีลักษณะแตกต่างกัน ดังตารางต่อไปนี้\nหินก้อนใดเป็นหินแปร',
#   'material': [{'type': 'list',
#     'data': ['หิน A หินที่มีเนื้อละเอียดและรูพรุนเป็นจำนวนมาก',
#      'หิน B หินที่มีผลึกแร่มีการเรียงตัวขนานกัน',
#      'หิน C หินที่มีเนื้อผลึกแร่ขนาดใหญ่',
#      'หิน D หินที่มีผลึกแร่ขนาดเล็กและมีซากดึกดำบรรพ์']}],
#   'choice': ['หิน A', 'หิน B', 'หิน C', 'หิน D'],
#   'answer': 2},
#  {'id': 15,
#   'question': 'จากการสำรวจหินดินดานบริเวณชายทะเลแห่งหนึ่ง พบซากดึกดำบรรพ์เกล็ดปลาน้ำจืด\nและรอยเท้าไดโนเสาร์อยู่ในชั้นหินเดียวกัน\nจากสถานการณ์ ข้อใดสรุปได้ถูกต้อง',
#   'choice': ['หินดินดานเกิดจากการสะสมตัวในสภาพแวดล้อมที่เป็นทะเล',
#    'ซากดึกดำบรรพ์ทั้งสองเกิดจากโครงร่างของสิ่งมีชีวิตในอดีดเหมือนกัน',
#    'ซากดึกดำบรรพ์ทั้งสองมีอายุเท่ากัน',
#    'ไดโนเสาร์ที่ทำให้เกิดรอยเท้ามีวิวัฒนาการมากกว่าปลาน้ำจืด'],
#   'answer': 3},
#  {'id': 16,
#   'question': 'จากรูป เรือกำลังแล่นเข้าสู่ชายฝั่งด้วยแรงลมเท่านั้น\nข้อใดกล่าวไม่ถูกต้อง',
#   'material': [{'type': 'image-desc',
#     'data': ['ภาพกราฟิคแบบการ์ตูนแสดงพื้นที่บริเวลาชายฝั่งทะเลที่มีบ้านตั้งอยู่บนหาดทรายและทางขวามือมีภาพเรือใบกำลังลอยอยู่ในทะเลมีรูปศรแสดงทิศทางของเรือที่ชี้ไปยังตัวบ้าน (ขึ้นฝั่ง)']}],
#   'choice': ['เหตุการณ์นี้เกิดในเวลากลางคืน',
#    'ลมที่พัดพาเรือกลับสู่ชายฝั่งคือ ลมทะเล',
#    'อากาดเหนือชายฝั่งมีอุณหภูมิสูงกว่าพื้นผิวน้ำทะเล',
#    'บนบกบริเวณชายฝั่งมีความกดอากาศต่ำกว่าในทะเล'],
#   'answer': 1},
#  {'id': 19.1,
#   'question': 'เห็ดสร้างอาหารเองได้เช่นเดียวกับพืช เพราะพบอยู่ในพื้นที่เดียวกันใช่หรือไม่',
#   'material': [{'type': 'text-info',
#     'data': ['ในการสำรวจพื้นที่แห่งหนึ่งซึ่งเป็นดินชื้นแฉะ พบดอกเห็ดสีขาวนวล 1 ชนิด และพบพืช\nอีก 2 ชนิด ชนิดแรกเห็นส่วนของลำต้นสีเขียวชูขึ้นเหนือดินมีใบสีเขียว ไม่พบดอก\nส่วนอีกชนิดหนึ่งไม่เห็นส่วนของลำต้น แต่มีส่วนคล้ายใบขนาดเล็กเรียงติดผิวดิน\nคล้ายพรม ไม่พบดอก']}],
#   'choice': ['ใช่', 'ไม่ใช่'],
#   'answer': 2},
#  {'id': 19.2,
#   'question': 'ถ้าถอนพืชทั้งสองชนิดจะพบราก หรือส่วนคล้ายรากที่ทำหน้าที่ในการดูดน้ำ ใช่หรือไม่',
#   'material': [{'type': 'text-info',
#     'data': ['ในการสำรวจพื้นที่แห่งหนึ่งซึ่งเป็นดินชื้นแฉะ พบดอกเห็ดสีขาวนวล 1 ชนิด และพบพืช\nอีก 2 ชนิด ชนิดแรกเห็นส่วนของลำต้นสีเขียวชูขึ้นเหนือดินมีใบสีเขียว ไม่พบดอก\nส่วนอีกชนิดหนึ่งไม่เห็นส่วนของลำต้น แต่มีส่วนคล้ายใบขนาดเล็กเรียงติดผิวดิน\nคล้ายพรม ไม่พบดอก']}],
#   'choice': ['ใช่', 'ไม่ใช่'],
#   'answer': 1},
#  {'id': 19.3,
#   'question': 'เราสามารถสรูปว่า ดอกไม่ได้เป็นโครงสร้างในการสืบพันธุ์แบบอาศัยเพศของพืชทั้งสองชนิด เพราะไม่พบดอก ใช่หรือไม่',
#   'material': [{'type': 'text-info',
#     'data': ['ในการสำรวจพื้นที่แห่งหนึ่งซึ่งเป็นดินชื้นแฉะ พบดอกเห็ดสีขาวนวล 1 ชนิด และพบพืช\nอีก 2 ชนิด ชนิดแรกเห็นส่วนของลำต้นสีเขียวชูขึ้นเหนือดินมีใบสีเขียว ไม่พบดอก\nส่วนอีกชนิดหนึ่งไม่เห็นส่วนของลำต้น แต่มีส่วนคล้ายใบขนาดเล็กเรียงติดผิวดิน\nคล้ายพรม ไม่พบดอก']}],
#   'choice': ['ใช่', 'ไม่ใช่'],
#   'answer': 2},
#  {'id': 20.1,
#   'question': 'ถ้าระยะห่างของน้ำตาเทียนกับเปลวไฟแตกต่างกัน ดังนั้น น้ำตาเทียนที่อยู่ใกล้เปลวไฟมากกว่า จะหลอมเหลวเร็วกว่า ใช่หรือไม่',
#   'material': [{'type': 'text-info',
#     'data': ['เด็กหญิงสมศรีทำการทดลองโดยนำน้ำตาเทียนหยดลงบนไม้บรรทัดที่ทำจากวัสดุ\nต่างกัน 2 ชนิด ได้แก่ เหล็ก และอะลูมิเนียม แล้วใช้เปลวไฟจากเทียนไขจ่อที่ปลาย\nอีกด้านหนึ่งของไม้บรรทัด โดยมีระยะห่างระหว่างเปลวไฟกับน้ำตาเทียนเท่ากัน\nบนไม้บรรทัดทั้งสองชนิด ดังภาพ\nเมื่อพิจารณาจากตัวแปรและวิธีการทดลองของสมศรี การตั้งสมมติฐานด้วยข้อความ\nต่อไปนี้เหมาะสมแล้ว ใช่หรือไม่']},
#    {'type': 'image-desc',
#     'data': ['ภาพแสดงการทดลองโดยมีเทียนหนึ่งเล่มจุดไฟแล้วกำลังจ่อปลายแท่งสี่เหลี่ยมแทนเป็นไม้บรรทัดที่ทำจากวัสดุชนิดต่าง ๆ และที่ปลายอีกด้านของสี่เหลี่ยมมีจุดสีดำซึ่งแทนน้ำตาเทียนที่หยดลงไป']}],
#   'choice': ['ใช่', 'ไม่ใช่'],
#   'answer': 2},
#  {'id': 20.2,
#   'question': 'ระยะห่างระหว่างน้ำตาเทียนกับเปลวไฟและขนิดของไม้บรรทัด มีผลต่อการหลอมเหลวของน้ำตาเทียน ใช่หรือไม่',
#   'material': [{'type': 'text-info',
#     'data': ['เด็กหญิงสมศรีทำการทดลองโดยนำน้ำตาเทียนหยดลงบนไม้บรรทัดที่ทำจากวัสดุ\nต่างกัน 2 ชนิด ได้แก่ เหล็ก และอะลูมิเนียม แล้วใช้เปลวไฟจากเทียนไขจ่อที่ปลาย\nอีกด้านหนึ่งของไม้บรรทัด โดยมีระยะห่างระหว่างเปลวไฟกับน้ำตาเทียนเท่ากัน\nบนไม้บรรทัดทั้งสองชนิด ดังภาพ\nเมื่อพิจารณาจากตัวแปรและวิธีการทดลองของสมศรี การตั้งสมมติฐานด้วยข้อความ\nต่อไปนี้เหมาะสมแล้ว ใช่หรือไม่']},
#    {'type': 'image-desc',
#     'data': ['ภาพแสดงการทดลองโดยมีเทียนหนึ่งเล่มจุดไฟแล้วกำลังจ่อปลายแท่งสี่เหลี่ยมแทนเป็นไม้บรรทัดที่ทำจากวัสดุชนิดต่าง ๆ และที่ปลายอีกด้านของสี่เหลี่ยมมีจุดสีดำซึ่งแทนน้ำตาเทียนที่หยดลงไป']}],
#   'choice': ['ใช่', 'ไม่ใช่'],
#   'answer': 2},
#  {'id': 20.3,
#   'question': 'ถ้าวัสดุต่างชนิดกันมีความสามารถในการนำความร้อนต่างกัน ดังนั้นไม้บรรทัดเหล็กสามารถนำความร้อนได้ดีกว่าอะลูมิเนียม ใช่หรือไม่',
#   'material': [{'type': 'text-info',
#     'data': ['เด็กหญิงสมศรีทำการทดลองโดยนำน้ำตาเทียนหยดลงบนไม้บรรทัดที่ทำจากวัสดุ\nต่างกัน 2 ชนิด ได้แก่ เหล็ก และอะลูมิเนียม แล้วใช้เปลวไฟจากเทียนไขจ่อที่ปลาย\nอีกด้านหนึ่งของไม้บรรทัด โดยมีระยะห่างระหว่างเปลวไฟกับน้ำตาเทียนเท่ากัน\nบนไม้บรรทัดทั้งสองชนิด ดังภาพ\nเมื่อพิจารณาจากตัวแปรและวิธีการทดลองของสมศรี การตั้งสมมติฐานด้วยข้อความ\nต่อไปนี้เหมาะสมแล้ว ใช่หรือไม่']},
#    {'type': 'image-desc',
#     'data': ['ภาพแสดงการทดลองโดยมีเทียนหนึ่งเล่มจุดไฟแล้วกำลังจ่อปลายแท่งสี่เหลี่ยมแทนเป็นไม้บรรทัดที่ทำจากวัสดุชนิดต่าง ๆ และที่ปลายอีกด้านของสี่เหลี่ยมมีจุดสีดำซึ่งแทนน้ำตาเทียนที่หยดลงไป']}],
#   'choice': ['ใช่', 'ไม่ใช่'],
#   'answer': 1}]

# %%
print(len(corpus))
# Out:
# 20

# %%
# Create Question for chat
cat_word = {
    'table': 'กำหนดตาราง',
    'list': '',
    'image-desc': 'ใช้คำบรรยายรูปภาพต่อไปนี้เพื่อตอบคำถาม',
    'text-info': '',
    '':''
}

for qidx, qi in enumerate(corpus[:4]):
    header = ""
    materials = qi.get('material', [])
    question_text = qi.get('question', '')
    choices = qi.get('choice', [])
    for mi in materials:
        mat_type = mi.get('type', '')
        mat_data = mi.get('data', [])

        if mat_type == 'table':
            header += f'{cat_word["table"]}\n'
            header += f'{mat_data}\n'
        else:
            for md in mat_data:
                header += md + '\n'
    header += f'{question_text}\n'

    print(f'คำถามข้อที่ {qidx+1} {header}')
    for ii, ci in enumerate(choices):
        print(f'{ii+1}. {ci}')

    print('-'*50)
# Out:
# คำถามข้อที่ 1 ความสัมพันธ์ระหว่างสิ่งมีชีวิตกับสิ่งมีชีวิตในข้อใดจัดเป็นการอยู่ร่วมกันในรูปแบบ "ภาวะพึ่งพาอาศัยกัน"
#
# 1. ปลาการ์ตูนกับปะการัง
# 2. ผึ้งกับดอกไม้
# 3. เห็บกับสุนัข
# 4. กล้วยไม้กับต้นมะค่า
# --------------------------------------------------
# คำถามข้อที่ 2 ในระบบย่อยอาหารของมนุษย์ การดูดซึมสารอาหารส่วนใหญ่เกิดขึ้นที่อวัยวะใด
#
# 1. ลำไส้เล็ก
# 2. ตับอ่อน
# 3. ลำไส้ใหญ่
# 4. กระเพาะอาหาร
# --------------------------------------------------
# คำถามข้อที่ 3 ครอบครัวหนึ่ง พ่อและแม่มีผมสั้นสีดำ พ่อมีผมเหยียดตรง แต่แม่มีผมหยิกเป็นคลื่น จากการดัดผม ลูกสาวทำสีผมเป็นสีทาและดัดหยิกเป็นคลื่นเช่นเดียวกับกุณยาย
# ข้อใดเป็นลักษณะทางพันธุกรรม
#
# 1. ลักษณะผมสั้นที่พบในพ่อและแม่
# 2. ลักษณะผมสีดำที่พบในพ่อและแม่
# 3. ลักษณะผมสีเทาของคุณยายและหลานที่เหมือนกัน
# 4. ลักษณะผมหยิกที่ถ่ายทอดจากรุ่นคุณยายสู่หลาน
# --------------------------------------------------
# คำถามข้อที่ 4 กำหนดตาราง
# <table> <tbody> <th > <td rowspan="2" >วัสดุ</td> <td colspan="2" >ความยาวของชิ้นงาน (เซนติเมตร)</td> </th> <tr > <td>ขณะดึงวัตถุ</td> <td>หลังปล่อย</td> </tr> <tr > <td>A</td> <td>16</td> <td >16</td> </tr> <tr> <td >B</td> <td >19</td> <td >18</td> </tr> <tr> <td >C</td> <td>15</td> <td>15</td> </tr> <tr > <td>D</td> <td>23</td> <td >15</td> </tr> </tbody></table>
# ในการทดลองเกี่ยวกับสภาพยืดหยุ่น นำชิ้นงานที่มีความยาวเริ่มต้น 15 เซนติเมตร ทำการดึงด้วยแรงเท่ากัน ได้ผลการทดลองดังตาราง
# วัสดุในข้อใดเหมาะในการนำมาทำเป็นยางรัดของ
#
# 1. A
# 2. B
# 3. C
# 4. D
# --------------------------------------------------

# %% [markdown]
# # Example ChatGPT Prompt:
# ```
# ตอบคำถามต่อไปนี้ พร้อมอธิบายเหตุผลสั้นๆ
# คำถามข้อที่ 1 ความสัมพันธ์ระหว่างสิ่งมีชีวิตกับสิ่งมีชีวิตในข้อใดจัดเป็นการอยู่ร่วมกันในรูปแบบ "ภาวะพึ่งพาอาศัยกัน"...
# ```
#
# __Result__
# ```
# คำตอบ:
#
# คำถามข้อที่ 1: 2. ผึ้งกับดอกไม้ - เพราะผึ้งจะไปเก็บเนื้อเยื่อพืชจากดอกไม้เป็นอาหาร และในขณะที่ผึ้งไปเก็บน้ำหวานจากดอกไม้กลับมาตั้งรัง เนื่องจากไม่สามารถทำได้เอง
#
# คำถามข้อที่ 2: 1. ลำไส้เล็ก - เพราะเป็นส่วนที่ดูดซึมสารอาหารจากอาหารที่ย่อยให้เป็นสารอาหารเข้าสู่เลือดและปล่อยให้เซลล์ของร่างกายนำไปใช้งาน
#
# คำถามข้อที่ 3: 4. ลักษณะผมหยิกที่ถ่ายทอดจากรุ่นคุณยายสู่หลาน - เพราะลักษณะผมหยิกเป็นลักษณะที่ถ่ายทอดต่อกันผ่านทางพันธุกรรม
#
# คำถามข้อที่ 4: 2. B - เพราะมีความยืดหยุ่นต่ำที่สุดระหว่างวัสดุ A, B, C, D โดยดูจากผลการทดลองการยืดตัวของชิ้นงานที่ดึงด้วยแรงเท่ากัน ทำให้วัสดุ B เหมาะสมกับการนำมาทำเป็นยางรัดของ
# ```
#
# __Evaluate__
# Q1: Correct
# Q2: Correct
# Q3: Wrong (2)
# Q4: Wrong (4)
